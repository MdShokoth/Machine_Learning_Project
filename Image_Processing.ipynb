# %% [markdown]
# <a href="https://colab.research.google.com/github/MdShokoth/Machine_Learning_Project/blob/main/Image_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#getting an image from web get
# !wget 'https://images.freeimages.com/images/large-previews/ee0/joyful-puppy-splashing-happiness-0410-5697282.jpg?fmt=webp&w=500'
# Out:
# --2024-12-22 07:50:01--  https://images.freeimages.com/images/large-previews/ee0/joyful-puppy-splashing-happiness-0410-5697282.jpg?fmt=webp&w=500
# Resolving images.freeimages.com (images.freeimages.com)... 108.156.201.33, 108.156.201.101, 108.156.201.100, ...
# Connecting to images.freeimages.com (images.freeimages.com)|108.156.201.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63518 (62K) [image/webp]
# Saving to: ‘joyful-puppy-splashing-happiness-0410-5697282.jpg?fmt=webp&w=500’
#
# joyful-puppy-splash 100%[===================>]  62.03K  --.-KB/s    in 0.1s
#
# 2024-12-22 07:50:01 (589 KB/s) - ‘joyful-puppy-splashing-happiness-0410-5697282.jpg?fmt=webp&w=500’ saved [63518/63518]

# %% [markdown]
# **libraries that can be used for image processing**
# 1. matplotlib.image
# 2. Pillow
# 3. OpenCV(cv2)

# %%
#importing image from matplotlib library
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# loading image from matplotlib.image module
img=mpimg.imread('joyful-puppy-splashing-happiness-0410-5697282.jpg?fmt=webp&w=500')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (400, 500, 3)

# %%
print(img)
# Out:
# [[[172 183 172]
#   [172 183 172]
#   [172 183 172]
#   ...
#   [ 53  62  50]
#   [ 57  66  54]
#   [ 56  65  52]]
#
#  [[171 181 171]
#   [171 181 171]
#   [171 181 171]
#   ...
#   [ 56  65  52]
#   [ 55  63  51]
#   [ 56  65  52]]
#
#  [[169 180 170]
#   [169 180 170]
#   [169 180 170]
#   ...
#   [ 51  61  51]
#   [ 55  66  56]
#   [ 55  66  56]]
#
#  ...
#
#  [[ 88 141 205]
#   [ 89 143 207]
#   [ 89 143 207]
#   ...
#   [164 136  86]
#   [165 137  85]
#   [165 137  85]]
#
#  [[ 89 145 208]
#   [ 90 146 209]
#   [ 90 146 209]
#   ...
#   [162 133  84]
#   [164 136  84]
#   [166 139  84]]
#
#  [[ 90 146 209]
#   [ 91 147 210]
#   [ 91 147 210]
#   ...
#   [159 131  81]
#   [163 135  83]
#   [165 138  83]]]

# %%
#displaying the image from numpy array
img_plt=plt.imshow(img)
plt.show()

# %% [markdown]
# Resizing image using Pillow Library

# %%
from PIL import Image
img=Image.open('joyful-puppy-splashing-happiness-0410-5697282.jpg?fmt=webp&w=500')
img_resize=img.resize((200,200))
img_resize.show()

# %%
img_resize.save('resized_image.jpg')

# %%
img_res=mpimg.imread('resized_image.jpg')
img_res_plt=plt.imshow(img)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# **converting RGB image to grayscale using OpenCV**

# %%
#importing opencv library
import cv2

# %%
img=cv2.imread('/content/joyful-puppy-splashing-happiness-0410-5697282.jpg?fmt=webp&w=500')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (400, 500, 3)

# %%
grayscale_image=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
grayscale_image.shape
# Out:
# (400, 500)

# %% [markdown]
# cv2.imshow() will display the image but this will not show in google colab.
# **from google.colab.patches import cv2_imshow()**

# %%
from google.colab.patches import cv2_imshow

# %%
#displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=500x400>

# %%
#saving the grayscale image
cv.imwrite('grayscale_image.jpg',grayscale_image)
